# %% [markdown]
# # YOLOv11 + BoT-SORT Tracking Pipeline
#
# Written by Rishit, ran on Google Colab w/ GPU

# %%
# !ffmpeg -version

# %%
from pathlib import Path
import os
import csv
import time
import json
import subprocess
import cv2

import numpy as np
import torch
from ultralytics import YOLO

# repo, data, results
REPO_ROOT = Path.cwd().resolve()
DATA_ROOT = REPO_ROOT / "data" / "soccer_side"
RESULTS_ROOT = REPO_ROOT / "results" / "yolov11_botsort"
RESULTS_ROOT.mkdir(parents=True, exist_ok=True)

print(f"Repo root: {REPO_ROOT}")
print(f"Data root: {DATA_ROOT}")
print(f"Results root: {RESULTS_ROOT}")

# runtime device
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", DEVICE)

# detection / tracking configs (kept near the top)
CONF_THRESHOLD = 0.25  # bumped from 0.15 to cut false positives
IOU_THRESHOLD = 0.5
PERSON_CLASS_ID = 0

# IMPORTANT: wide soccer videos need more resolution for small players
IMGSZ = 1920  

# video configs
VIDEO_EXTS = {".mp4", ".mkv", ".avi", ".mov"}
VIDEO_CODEC = "mp4v"  # for rendered videos later

# viz configs
BBOX_THICKNESS = 2
TEXT_FONT = cv2.FONT_HERSHEY_SIMPLEX
TEXT_SCALE = 0.6
TEXT_THICKNESS = 2
TEXT_Y_OFFSET = 10

# %%
# pre-process videos to *_fixed.mp4 so OpenCV + ffmpeg behave 
import subprocess
import glob

# NOTE: ran on Colab, will be different for local setups
ffmpeg_path = r"C:\Users\rishi\ffmpeg\bin\ffmpeg.exe"

if not os.path.exists(ffmpeg_path):
    print(f"[ERROR] ffmpeg not found at: {ffmpeg_path}")
    print("Update ffmpeg_path above if needed. Skipping preprocessing.")
else:
    print(f"Using ffmpeg at: {ffmpeg_path}")
    print("Pre-processing videos to *_fixed.mp4 ...")
    videos_processed = 0
    videos_skipped = 0
    videos_failed = 0

    for vid in glob.glob("data/soccer_side/**/*.mp4", recursive=True):
        if "_fixed.mp4" in vid: 
            continue

        fixed = vid.replace(".mp4", "_fixed.mp4")

        if not os.path.exists(fixed):
            print(f"Processing: {vid} -> {fixed}")
            try:
                result = subprocess.run([
                    ffmpeg_path, "-y", "-i", vid,
                    "-c:v", "libx264", "-pix_fmt", "yuv420p",
                    "-c:a", "aac", fixed
                ], capture_output=True, text=True, timeout=300)

                if result.returncode == 0:
                    videos_processed += 1
                else:
                    videos_failed += 1
            except subprocess.TimeoutExpired:
                videos_failed += 1
            except Exception as e:
                videos_failed += 1
        else:
            videos_skipped += 1

    print("\nPre-processing complete:")

# %%
def discover_sequences(data_root: Path):
    """
    Find sequences with both video and gt/gt.txt under data_root.
    - prefers *_fixed.mp4 if present, else falls back to .mp4/other
    - warns if multiple videos exist and picks the first alphabetically
    """
    seqs = []

    for gt_file in data_root.rglob("gt.txt"):
        gt_dir = gt_file.parent
        seq_dir = gt_dir.parent
        video_files = [
            p for p in seq_dir.iterdir()
            if p.is_file() and p.suffix.lower() in VIDEO_EXTS
        ]

        if not video_files:
            continue

        fixed_videos = [v for v in video_files if "_fixed.mp4" in v.name]
        if fixed_videos:
            video_files = fixed_videos
        else:
            mp4_videos = [v for v in video_files if v.suffix.lower() == ".mp4"]
            if mp4_videos:
                video_files = mp4_videos

        video_files.sort()
        video_path = video_files[0]
        if len(video_files) > 1:
            print(f"Warning: Multiple videos in {seq_dir}, using {video_path.name}")

        seqs.append(
            {
                "name": seq_dir.name,
                "seq_dir": seq_dir,
                "gt_path": gt_file,
                "video_path": video_path,
            }
        )

    return seqs

sequences = discover_sequences(DATA_ROOT)

print(f"Discovered {len(sequences)} sequence(s) with video + gt:")
for s in sequences:
    print(f"  - {s['name']}: video={s['video_path'].relative_to(REPO_ROOT)}, gt={s['gt_path'].relative_to(REPO_ROOT)}")

# %% [markdown]
# ## Initialize YOLO Model

# %%
# model weights
YOLO_WEIGHTS = "yolo11n.pt"
print(f"Loading YOLOv11 weights: {YOLO_WEIGHTS}")
yolo_model = YOLO(YOLO_WEIGHTS)
yolo_model.to(DEVICE)

# larger imgsz helps with tiny players on 6500x1000 frames
print(f"imgsz set to {IMGSZ}")

# %% [markdown]
# ## Main Processing Pipeline

# %%
def get_color_for_id(track_id: int):
    """Deterministic color per track ID for consistent overlays"""
    rng = np.random.RandomState(int(track_id))
    return tuple(int(c) for c in rng.randint(0, 255, 3))


def track_sequence_with_yolo_botsort(
    model: YOLO,
    video_path: Path,
    seq_name: str,
    save_dir: Path,
    classes=(PERSON_CLASS_ID,),
    conf: float = CONF_THRESHOLD,
    iou: float = IOU_THRESHOLD,
    imgsz: int = IMGSZ,
    device: str = DEVICE,
    save_video: bool = True,
):
    """
    Run YOLOv11 + BoT-SORT on a single video and export MOT-format detections

    Parameters:
    ----------
    model : YOLO
        Ultralytics YOLO instance
    video_path : Path
        Input video path
    seq_name : str
        Sequence name for output filenames
    save_dir : Path
        Directory for MOT txt (and videos if enabled)
    classes : tuple
        Class IDs to keep (default: person only)
    conf : float
        Confidence threshold
    iou : float
        IoU threshold for NMS
    imgsz : int
        Inference image size (bigger helps small players, slower)
    device : str
        "cuda" or "cpu"
    save_video : bool
        Save annotated video if True
    """
    save_dir.mkdir(parents=True, exist_ok=True)
    mot_out_path = save_dir / f"{seq_name}.txt"
    video_out_dir = save_dir / "videos"
    video_out_dir.mkdir(exist_ok=True)
    video_out_path = video_out_dir / f"{seq_name}_tracked.mp4"

    mot_file = open(mot_out_path, "w", newline="")
    writer = csv.writer(mot_file)

    frame_idx = 0
    t_start = time.time()

    video_writer = None
    if save_video:
        cap = cv2.VideoCapture(str(video_path))
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        cap.release()

        fourcc = cv2.VideoWriter_fourcc(*VIDEO_CODEC)
        video_writer = cv2.VideoWriter(str(video_out_path), fourcc, fps, (width, height))

    results_generator = model.track(
        source=str(video_path),
        tracker="botsort.yaml",
        conf=conf,
        iou=iou,
        classes=list(classes),
        imgsz=imgsz,
        device=device,
        stream=True,
        verbose=False,
        save=False,
    )

    num_det_total = 0
    for res in results_generator:
        frame_idx += 1 
        boxes = res.boxes
        frame_to_write = res.orig_img.copy() if save_video and video_writer is not None else None

        if boxes is None or boxes.id is None:
            if frame_to_write is not None:
                video_writer.write(frame_to_write)
            continue

        ids = boxes.id.cpu().numpy().astype(int)
        xyxy = boxes.xyxy.cpu().numpy()
        confs = boxes.conf.cpu().numpy()

        for trk_id, (x1, y1, x2, y2), c in zip(ids, xyxy, confs):
            w = x2 - x1
            h = y2 - y1
            writer.writerow([
                frame_idx,
                int(trk_id),
                float(x1),
                float(y1),
                float(w),
                float(h),
                float(c),
                -1, -1, -1,
            ])
            num_det_total += 1

            if frame_to_write is not None:
                color = get_color_for_id(trk_id)
                cv2.rectangle(frame_to_write, (int(x1), int(y1)), (int(x2), int(y2)), color, BBOX_THICKNESS)
                cv2.putText(
                    frame_to_write,
                    f"ID:{int(trk_id)} ({c:.2f})",
                    (int(x1), int(y1) - TEXT_Y_OFFSET),
                    TEXT_FONT,
                    TEXT_SCALE,
                    color,
                    TEXT_THICKNESS,
                )

        if frame_to_write is not None:
            video_writer.write(frame_to_write)

    mot_file.close()
    if save_video and video_writer is not None:
        video_writer.release()

    elapsed = time.time() - t_start
    fps_out = frame_idx / elapsed if elapsed > 0 else 0

    print(f"[{seq_name}] Wrote {num_det_total} detections to {mot_out_path}")
    if save_video and video_out_path.exists():
        print(f"[{seq_name}] Saved annotated video to {video_out_path}")
    print(f"[{seq_name}] Time: {elapsed:.2f}s, FPS ~ {fps_out:.2f}")

    return {
        "sequence_name": seq_name,
        "total_frames": frame_idx,
        "total_detections": num_det_total,
        "processing_time": elapsed,
        "average_fps": fps_out,
        "mot_file": str(mot_out_path),
        "video_file": str(video_out_path) if save_video else None,
    }

# %% [markdown]
# ## Run Pipeline, Save Results

# %%
mot_results_dir = RESULTS_ROOT / "mot_outputs"
mot_results_dir.mkdir(parents=True, exist_ok=True)

# only process test sequences 
test_sequences = [s for s in sequences if "test" in str(s["seq_dir"]) ]

if not test_sequences:
    print("No test sequences found")
else:
    print(f"\nProcessing {len(test_sequences)} test sequence(s) with YOLOv11 + BoT-SORT...\n")

all_metrics = []

for seq in test_sequences:
    name = seq["name"]
    video_path = seq["video_path"]
    print(f"Video: {video_path}")

    metrics = track_sequence_with_yolo_botsort(
        model=yolo_model,
        video_path=video_path,
        seq_name=name,
        save_dir=mot_results_dir,
        classes=(PERSON_CLASS_ID,),
        conf=CONF_THRESHOLD,
        iou=IOU_THRESHOLD,
        imgsz=IMGSZ,
        device=DEVICE,
        save_video=True,
    )

    if metrics:
        all_metrics.append(metrics)

metrics_file = RESULTS_ROOT / "metrics.json"
with open(metrics_file, "w") as f:
    json.dump(all_metrics, f, indent=2)

print("\n sequences processed. Output MOT files:")
for m in all_metrics:
    print(f"  - {m['sequence_name']}: {Path(m['mot_file']).relative_to(REPO_ROOT)}")

print(f"\nMetrics saved to: {metrics_file}")
if all_metrics:
    total_frames = sum(m["total_frames"] for m in all_metrics)
    total_time = sum(m["processing_time"] for m in all_metrics)
    avg_fps = sum(m["average_fps"] for m in all_metrics) / len(all_metrics)
    total_detections = sum(m["total_detections"] for m in all_metrics)

    print("\nSummary Statistics:")
    print(f"  - Total frames processed: {total_frames}")
    print(f"  - Total processing time: {total_time:.2f}s")
    print(f"  - Average FPS: {avg_fps:.2f}")
    print(f"  - Total detections: {total_detections}")
