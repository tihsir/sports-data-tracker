# %%
# !ffmpeg -version
# Out:
# 'ffmpeg' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from pathlib import Path
import os
import csv
import time

import numpy as np
import torch
from ultralytics import YOLO

# Root paths (work relative to repo root)
REPO_ROOT = Path.cwd().resolve()
DATA_ROOT = REPO_ROOT / "data" / "soccer_side"
RESULTS_ROOT = REPO_ROOT / "results" / "yolov11_botsort"

RESULTS_ROOT.mkdir(parents=True, exist_ok=True)

print(f"Repo root: {REPO_ROOT}")
print(f"Data root: {DATA_ROOT}")
print(f"Results root: {RESULTS_ROOT}")

# Device selection
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"

print("Using device:", DEVICE)
# Out:
# Repo root: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker
# Data root: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side
# Results root: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort
# Using device: cpu

# %%
# Pre-process videos: convert to fixed format using ffmpeg
# This ensures compatibility with video processing libraries
import subprocess
import glob
# Use specific ffmpeg path
ffmpeg_path = r"C:\Users\rishi\ffmpeg\bin\ffmpeg.exe"

# Check if ffmpeg exists at the specified path
if not os.path.exists(ffmpeg_path):
    print(f"[ERROR] ffmpeg not found at: {ffmpeg_path}")
    print("Please update the ffmpeg_path variable in this cell with the correct path.")
    print("Skipping video preprocessing.")
else:
    print(f"Using ffmpeg at: {ffmpeg_path}")
    print("Pre-processing videos to fixed format...")
    videos_processed = 0
    videos_skipped = 0
    videos_failed = 0

    for vid in glob.glob("data/soccer_side/**/*.mp4", recursive=True):
        # Skip if it's already a _fixed.mp4 file
        if "_fixed.mp4" in vid:
            continue
        
        fixed = vid.replace(".mp4", "_fixed.mp4")
        
        if not os.path.exists(fixed):
            print(f"Processing: {vid} -> {fixed}")
            try:
                result = subprocess.run([
                    ffmpeg_path, "-y", "-i", vid,
                    "-c:v", "libx264", "-pix_fmt", "yuv420p",
                    "-c:a", "aac", fixed
                ], capture_output=True, text=True, timeout=300)  # 5 minute timeout per video
                
                if result.returncode == 0:
                    videos_processed += 1
                    print(f"  ✓ Success")
                else:
                    videos_failed += 1
                    print(f"  ✗ Failed: {result.stderr[:200]}")  # Show first 200 chars of error
            except subprocess.TimeoutExpired:
                videos_failed += 1
                print(f"  ✗ Timeout (video too long or stuck)")
            except Exception as e:
                videos_failed += 1
                print(f"  ✗ Error: {str(e)}")
        else:
            videos_skipped += 1

    print(f"\nPre-processing complete:")
    print(f"  - Processed: {videos_processed} video(s)")
    print(f"  - Already fixed: {videos_skipped} video(s)")
    if videos_failed > 0:
        print(f"  - Failed: {videos_failed} video(s)")
# Out:
# Using ffmpeg at: C:\Users\rishi\ffmpeg\bin\ffmpeg.exe
# Pre-processing videos to fixed format...
# Processing: data/soccer_side\test\F_20220220_1_1680_1710\img1.mp4 -> data/soccer_side\test\F_20220220_1_1680_1710\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\test\F_20220220_1_1710_1740\img1.mp4 -> data/soccer_side\test\F_20220220_1_1710_1740\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\test\F_20220220_1_1740_1770\img1.mp4 -> data/soccer_side\test\F_20220220_1_1740_1770\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\test\F_20220220_1_1770_1800\img1.mp4 -> data/soccer_side\test\F_20220220_1_1770_1800\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\test\F_20220220_1_1800_1830\img1.mp4 -> data/soccer_side\test\F_20220220_1_1800_1830\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\test\F_20220220_1_1830_1860\img1.mp4 -> data/soccer_side\test\F_20220220_1_1830_1860\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\test\F_20220220_1_1860_1890\img1.mp4 -> data/soccer_side\test\F_20220220_1_1860_1890\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\test\F_20220220_1_1890_1920\img1.mp4 -> data/soccer_side\test\F_20220220_1_1890_1920\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\test\F_20220220_1_1920_1950\img1.mp4 -> data/soccer_side\test\F_20220220_1_1920_1950\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\test\F_20220220_1_1950_1980\img1.mp4 -> data/soccer_side\test\F_20220220_1_1950_1980\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20200220_1_0060_0090\img1.mp4 -> data/soccer_side\train\F_20200220_1_0060_0090\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20200220_1_0180_0210\img1.mp4 -> data/soccer_side\train\F_20200220_1_0180_0210\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20200220_1_0330_0360\img1.mp4 -> data/soccer_side\train\F_20200220_1_0330_0360\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20200220_1_0540_0570\img1.mp4 -> data/soccer_side\train\F_20200220_1_0540_0570\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20200220_1_0690_0720\img1.mp4 -> data/soccer_side\train\F_20200220_1_0690_0720\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20200220_1_0780_0810\img1.mp4 -> data/soccer_side\train\F_20200220_1_0780_0810\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20220220_1_0900_0930\img1.mp4 -> data/soccer_side\train\F_20220220_1_0900_0930\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20220220_1_0960_0990\img1.mp4 -> data/soccer_side\train\F_20220220_1_0960_0990\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20220220_1_0990_1020\img1.mp4 -> data/soccer_side\train\F_20220220_1_0990_1020\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20220220_1_1080_1110\img1.mp4 -> data/soccer_side\train\F_20220220_1_1080_1110\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20220220_1_1200_1230\img1.mp4 -> data/soccer_side\train\F_20220220_1_1200_1230\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\train\F_20220220_1_1260_1290\img1.mp4 -> data/soccer_side\train\F_20220220_1_1260_1290\img1_fixed.mp4
#   ✓ Success
#
# Pre-processing complete:
#   - Processed: 22 video(s)
#   - Already fixed: 0 video(s)

# %%
VIDEO_EXTS = {".mp4", ".mkv", ".avi", ".mov"}

def discover_sequences(data_root: Path):
    """
    Discover all sequences under data_root that:
    - Have a gt/gt.txt file
    - Have at least one video file in the same parent directory as gt/
    
    Prefers _fixed.mp4 files over regular .mp4 files for better compatibility.
    """
    seqs = []

    for gt_file in data_root.rglob("gt.txt"):
        gt_dir = gt_file.parent              # .../seq_name/gt
        seq_dir = gt_dir.parent              # .../seq_name
        video_files = [
            p for p in seq_dir.iterdir()
            if p.is_file() and p.suffix.lower() in VIDEO_EXTS
        ]

        if not video_files:
            # No video attached to this gt; skip
            continue

        # Prefer _fixed.mp4 files over regular .mp4 files
        fixed_videos = [v for v in video_files if "_fixed.mp4" in v.name]
        if fixed_videos:
            # Use _fixed.mp4 if available
            video_files = fixed_videos
        else:
            # Otherwise prefer .mp4 over other formats
            mp4_videos = [v for v in video_files if v.suffix.lower() == ".mp4"]
            if mp4_videos:
                video_files = mp4_videos

        # If multiple videos exist, pick the first alphabetically and warn
        video_files.sort()
        video_path = video_files[0]
        if len(video_files) > 1:
            print(f"[WARN] Multiple videos in {seq_dir}, using {video_path.name}")

        seqs.append(
            {
                "name": seq_dir.name,
                "seq_dir": seq_dir,
                "gt_path": gt_file,
                "video_path": video_path,
            }
        )

    return seqs

sequences = discover_sequences(DATA_ROOT)

print(f"Discovered {len(sequences)} sequence(s) with video + gt:")
for s in sequences:
    print(f"  - {s['name']}: video={s['video_path'].relative_to(REPO_ROOT)}, gt={s['gt_path'].relative_to(REPO_ROOT)}")
# Out:
# Discovered 22 sequence(s) with video + gt:
#   - F_20220220_1_1680_1710: video=data\soccer_side\test\F_20220220_1_1680_1710\img1_fixed.mp4, gt=data\soccer_side\test\F_20220220_1_1680_1710\gt\gt.txt
#   - F_20220220_1_1710_1740: video=data\soccer_side\test\F_20220220_1_1710_1740\img1_fixed.mp4, gt=data\soccer_side\test\F_20220220_1_1710_1740\gt\gt.txt
#   - F_20220220_1_1740_1770: video=data\soccer_side\test\F_20220220_1_1740_1770\img1_fixed.mp4, gt=data\soccer_side\test\F_20220220_1_1740_1770\gt\gt.txt
#   - F_20220220_1_1770_1800: video=data\soccer_side\test\F_20220220_1_1770_1800\img1_fixed.mp4, gt=data\soccer_side\test\F_20220220_1_1770_1800\gt\gt.txt
#   - F_20220220_1_1800_1830: video=data\soccer_side\test\F_20220220_1_1800_1830\img1_fixed.mp4, gt=data\soccer_side\test\F_20220220_1_1800_1830\gt\gt.txt
#   - F_20220220_1_1830_1860: video=data\soccer_side\test\F_20220220_1_1830_1860\img1_fixed.mp4, gt=data\soccer_side\test\F_20220220_1_1830_1860\gt\gt.txt
#   - F_20220220_1_1860_1890: video=data\soccer_side\test\F_20220220_1_1860_1890\img1_fixed.mp4, gt=data\soccer_side\test\F_20220220_1_1860_1890\gt\gt.txt
#   - F_20220220_1_1890_1920: video=data\soccer_side\test\F_20220220_1_1890_1920\img1_fixed.mp4, gt=data\soccer_side\test\F_20220220_1_1890_1920\gt\gt.txt
#   - F_20220220_1_1920_1950: video=data\soccer_side\test\F_20220220_1_1920_1950\img1_fixed.mp4, gt=data\soccer_side\test\F_20220220_1_1920_1950\gt\gt.txt
#   - F_20220220_1_1950_1980: video=data\soccer_side\test\F_20220220_1_1950_1980\img1_fixed.mp4, gt=data\soccer_side\test\F_20220220_1_1950_1980\gt\gt.txt
#   - F_20200220_1_0060_0090: video=data\soccer_side\train\F_20200220_1_0060_0090\img1_fixed.mp4, gt=data\soccer_side\train\F_20200220_1_0060_0090\gt\gt.txt
#   - F_20200220_1_0180_0210: video=data\soccer_side\train\F_20200220_1_0180_0210\img1_fixed.mp4, gt=data\soccer_side\train\F_20200220_1_0180_0210\gt\gt.txt
#   - F_20200220_1_0330_0360: video=data\soccer_side\train\F_20200220_1_0330_0360\img1_fixed.mp4, gt=data\soccer_side\train\F_20200220_1_0330_0360\gt\gt.txt
#   - F_20200220_1_0540_0570: video=data\soccer_side\train\F_20200220_1_0540_0570\img1_fixed.mp4, gt=data\soccer_side\train\F_20200220_1_0540_0570\gt\gt.txt
#   - F_20200220_1_0690_0720: video=data\soccer_side\train\F_20200220_1_0690_0720\img1_fixed.mp4, gt=data\soccer_side\train\F_20200220_1_0690_0720\gt\gt.txt
#   - F_20200220_1_0780_0810: video=data\soccer_side\train\F_20200220_1_0780_0810\img1_fixed.mp4, gt=data\soccer_side\train\F_20200220_1_0780_0810\gt\gt.txt
#   - F_20220220_1_0900_0930: video=data\soccer_side\train\F_20220220_1_0900_0930\img1_fixed.mp4, gt=data\soccer_side\train\F_20220220_1_0900_0930\gt\gt.txt
#   - F_20220220_1_0960_0990: video=data\soccer_side\train\F_20220220_1_0960_0990\img1_fixed.mp4, gt=data\soccer_side\train\F_20220220_1_0960_0990\gt\gt.txt
#   - F_20220220_1_0990_1020: video=data\soccer_side\train\F_20220220_1_0990_1020\img1_fixed.mp4, gt=data\soccer_side\train\F_20220220_1_0990_1020\gt\gt.txt
#   - F_20220220_1_1080_1110: video=data\soccer_side\train\F_20220220_1_1080_1110\img1_fixed.mp4, gt=data\soccer_side\train\F_20220220_1_1080_1110\gt\gt.txt
#   - F_20220220_1_1200_1230: video=data\soccer_side\train\F_20220220_1_1200_1230\img1_fixed.mp4, gt=data\soccer_side\train\F_20220220_1_1200_1230\gt\gt.txt
#   - F_20220220_1_1260_1290: video=data\soccer_side\train\F_20220220_1_1260_1290\img1_fixed.mp4, gt=data\soccer_side\train\F_20220220_1_1260_1290\gt\gt.txt

# %%
# You can switch to 'yolo11s.pt' or larger if you want better accuracy and have GPU resources
YOLO_WEIGHTS = "yolo11n.pt"   # or "yolo11s.pt"

print(f"Loading YOLOv11 model from weights: {YOLO_WEIGHTS}")
yolo_model = YOLO(YOLO_WEIGHTS)
yolo_model.to(DEVICE)

# COCO class index for 'person' is 0
PERSON_CLASS_ID = 0
# Out:
# Loading YOLOv11 model from weights: yolo11n.pt

# %%
def track_sequence_with_yolo_botsort(
    model: YOLO,
    video_path: Path,
    seq_name: str,
    save_dir: Path,
    classes=(PERSON_CLASS_ID,),
    conf: float = 0.15,
    iou: float = 0.5,
    device: str = DEVICE,
    save_video: bool = True,
):
    """
    Run YOLOv11 + BoT-SORT on a single video and export detections in MOT format.
    Optionally saves annotated video with tracking visualizations in MP4 format.

    Parameters
    ----------
    model : YOLO
        Ultralytics YOLO model instance.
    video_path : Path
        Path to the input video.
    seq_name : str
        Name of the sequence (used for result filename).
    save_dir : Path
        Directory to write MOT-format result file into.
    classes : tuple
        Tuple of class IDs to keep (default: person only).
    conf : float
        Confidence threshold.
    iou : float
        IoU threshold for NMS.
    device : str
        "cuda" or "cpu".
    save_video : bool
        If True, save annotated video with tracking visualizations.
    """
    import cv2
    
    save_dir.mkdir(parents=True, exist_ok=True)
    mot_out_path = save_dir / f"{seq_name}.txt"
    video_out_dir = save_dir / "videos"
    video_out_dir.mkdir(exist_ok=True)
    video_out_path = video_out_dir / f"{seq_name}_tracked.mp4"

    # Open CSV writer for MOTChallenge-style output
    f = open(mot_out_path, "w", newline="")
    writer = csv.writer(f)

    frame_idx = 0
    t_start = time.time()

    # Initialize video writer if saving video
    video_writer = None
    temp_video_path = None
    if save_video:
        # Get video properties from input video
        cap = cv2.VideoCapture(str(video_path))
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        cap.release()
        
        # Write to temporary file first, then re-encode with ffmpeg for proper H.264
        temp_video_path = video_out_path.parent / f"{video_out_path.stem}_temp.avi"
        # Use XVID for temporary file (works reliably on Windows)
        fourcc = cv2.VideoWriter_fourcc(*'XVID')
        video_writer = cv2.VideoWriter(str(temp_video_path), fourcc, fps, (width, height))

    # Run tracking - use streaming mode to process frame by frame
    # This allows us to manually write MP4 videos
    results_generator = model.track(
        source=str(video_path),
        tracker="botsort.yaml",
        conf=conf,
        iou=iou,
        classes=list(classes),
        device=device,
        stream=True,  # Use streaming to get annotated frames
        verbose=False,
        save=False,  # Don't use Ultralytics' built-in saving (saves as AVI)
    )

    # Process results to write MOT format and save video frames
    num_det_total = 0
    for res in results_generator:
        frame_idx += 1  # MOT frames are 1-based
        boxes = res.boxes

        # Get annotated frame (with bounding boxes drawn)
        annotated_frame = res.plot()  # This returns the frame with annotations
        
        # Write frame to video if saving
        if save_video and video_writer is not None:
            # Convert BGR to RGB (plot() returns RGB, OpenCV needs BGR)
            frame_bgr = cv2.cvtColor(annotated_frame, cv2.COLOR_RGB2BGR)
            video_writer.write(frame_bgr)

        if boxes is None or boxes.id is None:
            continue

        ids = boxes.id.cpu().numpy().astype(int)
        xyxy = boxes.xyxy.cpu().numpy()
        confs = boxes.conf.cpu().numpy()

        for trk_id, (x1, y1, x2, y2), c in zip(ids, xyxy, confs):
            w = x2 - x1
            h = y2 - y1

            # MOT format: frame, id, bb_left, bb_top, bb_width, bb_height, conf, -1, -1, -1
            writer.writerow([
                frame_idx,
                int(trk_id),
                float(x1),
                float(y1),
                float(w),
                float(h),
                float(c),
                -1,
                -1,
                -1,
            ])
            num_det_total += 1

    f.close()
    if save_video and video_writer is not None:
        video_writer.release()
        
        # Re-encode to H.264 MP4 using ffmpeg for better compatibility
        if temp_video_path and temp_video_path.exists():
            import subprocess
            import shutil
            
            # Try to find ffmpeg
            ffmpeg_cmd = None
            for possible_path in [
                "ffmpeg",
                r"C:\Users\rishi\ffmpeg\bin\ffmpeg.exe",
                shutil.which("ffmpeg")
            ]:
                if possible_path and (possible_path == "ffmpeg" or (isinstance(possible_path, str) and Path(possible_path).exists())):
                    ffmpeg_cmd = possible_path
                    break
            
            if ffmpeg_cmd:
                try:
                    # Use ffmpeg to re-encode to H.264 MP4
                    subprocess.run([
                        ffmpeg_cmd, "-y", "-i", str(temp_video_path),
                        "-c:v", "libx264", "-preset", "medium", "-crf", "23",
                        "-c:a", "copy",  # Copy audio if present
                        "-pix_fmt", "yuv420p",  # Ensure compatibility
                        str(video_out_path)
                    ], check=True, capture_output=True)
                    # Remove temporary file
                    temp_video_path.unlink()
                except (subprocess.CalledProcessError, FileNotFoundError) as e:
                    # If ffmpeg fails, just rename the temp file
                    print(f"[{seq_name}] Warning: ffmpeg re-encoding failed, using temporary file: {e}")
                    if video_out_path.exists():
                        video_out_path.unlink()
                    temp_video_path.rename(video_out_path)
            else:
                # No ffmpeg found, just rename temp file
                if video_out_path.exists():
                    video_out_path.unlink()
                temp_video_path.rename(video_out_path)
    
    t_end = time.time()
    elapsed = t_end - t_start

    print(f"[{seq_name}] Wrote {num_det_total} detections to {mot_out_path}")
    if save_video and video_out_path.exists():
        print(f"[{seq_name}] Saved annotated video to {video_out_path}")
    print(f"[{seq_name}] Time: {elapsed:.2f}s, FPS ~ {frame_idx / elapsed if elapsed > 0 else 0:.2f}")

    return mot_out_path

# %%
mot_results_dir = RESULTS_ROOT / "mot_outputs"
mot_results_dir.mkdir(parents=True, exist_ok=True)

result_paths = {}

for seq in sequences:
    name = seq["name"]
    video_path = seq["video_path"]

    print(f"\n=== Running YOLOv11 + BoT-SORT on sequence: {name} ===")
    print(f"Video: {video_path}")

    out_path = track_sequence_with_yolo_botsort(
        model=yolo_model,
        video_path=video_path,
        seq_name=name,
        save_dir=mot_results_dir,
        classes=(PERSON_CLASS_ID,),
        conf=0.15,
        iou=0.5,
        device=DEVICE,
    )
    result_paths[name] = out_path

print("\nAll sequences processed. Output MOT files:")
for name, path in result_paths.items():
    print(f"  - {name}: {path.relative_to(REPO_ROOT)}")
# Out:
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1680_1710 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1680_1710\img1_fixed.mp4
# [F_20220220_1_1680_1710] Wrote 69 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1680_1710.txt
# [F_20220220_1_1680_1710] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1680_1710_tracked.mp4
# [F_20220220_1_1680_1710] Time: 115.60s, FPS ~ 6.49
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1710_1740 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1710_1740\img1_fixed.mp4
# [F_20220220_1_1710_1740] Wrote 0 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1710_1740.txt
# [F_20220220_1_1710_1740] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1710_1740_tracked.mp4
# [F_20220220_1_1710_1740] Time: 111.01s, FPS ~ 6.76
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1740_1770 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1740_1770\img1_fixed.mp4
# [F_20220220_1_1740_1770] Wrote 108 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1740_1770.txt
# [F_20220220_1_1740_1770] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1740_1770_tracked.mp4
# [F_20220220_1_1740_1770] Time: 111.24s, FPS ~ 6.74
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1770_1800 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1770_1800\img1_fixed.mp4
# [F_20220220_1_1770_1800] Wrote 384 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1770_1800.txt
# [F_20220220_1_1770_1800] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1770_1800_tracked.mp4
# [F_20220220_1_1770_1800] Time: 113.86s, FPS ~ 6.59
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1800_1830 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1800_1830\img1_fixed.mp4
# [F_20220220_1_1800_1830] Wrote 89 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1800_1830.txt
# [F_20220220_1_1800_1830] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1800_1830_tracked.mp4
# [F_20220220_1_1800_1830] Time: 113.20s, FPS ~ 6.63
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1830_1860 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1830_1860\img1_fixed.mp4
# [F_20220220_1_1830_1860] Wrote 10 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1830_1860.txt
# [F_20220220_1_1830_1860] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1830_1860_tracked.mp4
# [F_20220220_1_1830_1860] Time: 111.78s, FPS ~ 6.71
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1860_1890 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1860_1890\img1_fixed.mp4
# [F_20220220_1_1860_1890] Wrote 94 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1860_1890.txt
# [F_20220220_1_1860_1890] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1860_1890_tracked.mp4
# [F_20220220_1_1860_1890] Time: 111.55s, FPS ~ 6.72
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1890_1920 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1890_1920\img1_fixed.mp4
# [F_20220220_1_1890_1920] Wrote 225 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1890_1920.txt
# [F_20220220_1_1890_1920] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1890_1920_tracked.mp4
# [F_20220220_1_1890_1920] Time: 112.41s, FPS ~ 6.67
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1920_1950 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1920_1950\img1_fixed.mp4
# [F_20220220_1_1920_1950] Wrote 2 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1920_1950.txt
# [F_20220220_1_1920_1950] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1920_1950_tracked.mp4
# [F_20220220_1_1920_1950] Time: 111.25s, FPS ~ 6.74
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1950_1980 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1950_1980\img1_fixed.mp4
# [F_20220220_1_1950_1980] Wrote 129 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1950_1980.txt
# [F_20220220_1_1950_1980] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1950_1980_tracked.mp4
# [F_20220220_1_1950_1980] Time: 111.00s, FPS ~ 6.76
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0000_0030 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0000_0030\img1_fixed.mp4
# [F_20200220_1_0000_0030] Wrote 10 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0000_0030.txt
# [F_20200220_1_0000_0030] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0000_0030_tracked.mp4
# [F_20200220_1_0000_0030] Time: 109.50s, FPS ~ 6.85
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0030_0060 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0030_0060\img1_fixed.mp4
# [F_20200220_1_0030_0060] Wrote 0 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0030_0060.txt
# [F_20200220_1_0030_0060] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0030_0060_tracked.mp4
# [F_20200220_1_0030_0060] Time: 109.68s, FPS ~ 6.84
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0060_0090 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0060_0090\img1_fixed.mp4
# [F_20200220_1_0060_0090] Wrote 7 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0060_0090.txt
# [F_20200220_1_0060_0090] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0060_0090_tracked.mp4
# [F_20200220_1_0060_0090] Time: 110.36s, FPS ~ 6.80
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0090_0120 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0090_0120\img1_fixed.mp4
# [F_20200220_1_0090_0120] Wrote 0 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0090_0120.txt
# [F_20200220_1_0090_0120] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0090_0120_tracked.mp4
# [F_20200220_1_0090_0120] Time: 108.61s, FPS ~ 6.91
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0120_0150 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0120_0150\img1_fixed.mp4
# [F_20200220_1_0120_0150] Wrote 6 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0120_0150.txt
# [F_20200220_1_0120_0150] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0120_0150_tracked.mp4
# [F_20200220_1_0120_0150] Time: 113.48s, FPS ~ 6.61
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0150_0180 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0150_0180\img1_fixed.mp4
# [F_20200220_1_0150_0180] Wrote 69 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0150_0180.txt
# [F_20200220_1_0150_0180] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0150_0180_tracked.mp4
# [F_20200220_1_0150_0180] Time: 124.54s, FPS ~ 6.02
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0180_0210 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0180_0210\img1_fixed.mp4
# [F_20200220_1_0180_0210] Wrote 320 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0180_0210.txt
# [F_20200220_1_0180_0210] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0180_0210_tracked.mp4
# [F_20200220_1_0180_0210] Time: 117.71s, FPS ~ 6.37
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0210_0240 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0210_0240\img1_fixed.mp4
# [F_20200220_1_0210_0240] Wrote 42 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0210_0240.txt
# [F_20200220_1_0210_0240] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0210_0240_tracked.mp4
# [F_20200220_1_0210_0240] Time: 111.44s, FPS ~ 6.73
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0240_0270 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0240_0270\img1_fixed.mp4
# [F_20200220_1_0240_0270] Wrote 9 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0240_0270.txt
# [F_20200220_1_0240_0270] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0240_0270_tracked.mp4
# [F_20200220_1_0240_0270] Time: 112.23s, FPS ~ 6.68
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0270_0300 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0270_0300\img1_fixed.mp4
# [F_20200220_1_0270_0300] Wrote 91 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0270_0300.txt
# [F_20200220_1_0270_0300] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0270_0300_tracked.mp4
# [F_20200220_1_0270_0300] Time: 110.14s, FPS ~ 6.81
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0300_0330 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0300_0330\img1_fixed.mp4
# [F_20200220_1_0300_0330] Wrote 48 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0300_0330.txt
# [F_20200220_1_0300_0330] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0300_0330_tracked.mp4
# [F_20200220_1_0300_0330] Time: 109.27s, FPS ~ 6.86
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0330_0360 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0330_0360\img1_fixed.mp4
# [F_20200220_1_0330_0360] Wrote 97 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0330_0360.txt
# [F_20200220_1_0330_0360] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0330_0360_tracked.mp4
# [F_20200220_1_0330_0360] Time: 108.67s, FPS ~ 6.90
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0360_0390 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0360_0390\img1_fixed.mp4
# [F_20200220_1_0360_0390] Wrote 38 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0360_0390.txt
# [F_20200220_1_0360_0390] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0360_0390_tracked.mp4
# [F_20200220_1_0360_0390] Time: 109.47s, FPS ~ 6.85
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0390_0420 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0390_0420\img1_fixed.mp4
# [F_20200220_1_0390_0420] Wrote 19 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0390_0420.txt
# [F_20200220_1_0390_0420] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0390_0420_tracked.mp4
# [F_20200220_1_0390_0420] Time: 113.00s, FPS ~ 6.64
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0420_0450 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0420_0450\img1_fixed.mp4
# [F_20200220_1_0420_0450] Wrote 32 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0420_0450.txt
# [F_20200220_1_0420_0450] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0420_0450_tracked.mp4
# [F_20200220_1_0420_0450] Time: 112.70s, FPS ~ 6.65
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0450_0480 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0450_0480\img1_fixed.mp4
# [F_20200220_1_0450_0480] Wrote 31 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0450_0480.txt
# [F_20200220_1_0450_0480] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0450_0480_tracked.mp4
# [F_20200220_1_0450_0480] Time: 113.26s, FPS ~ 6.62
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0480_0510 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0480_0510\img1_fixed.mp4
# [F_20200220_1_0480_0510] Wrote 42 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0480_0510.txt
# [F_20200220_1_0480_0510] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0480_0510_tracked.mp4
# [F_20200220_1_0480_0510] Time: 110.79s, FPS ~ 6.77
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0510_0540 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0510_0540\img1_fixed.mp4
# [F_20200220_1_0510_0540] Wrote 0 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0510_0540.txt
# [F_20200220_1_0510_0540] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0510_0540_tracked.mp4
# [F_20200220_1_0510_0540] Time: 110.18s, FPS ~ 6.81
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0540_0570 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0540_0570\img1_fixed.mp4
# [F_20200220_1_0540_0570] Wrote 39 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0540_0570.txt
# [F_20200220_1_0540_0570] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0540_0570_tracked.mp4
# [F_20200220_1_0540_0570] Time: 114.98s, FPS ~ 6.52
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0570_0600 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0570_0600\img1_fixed.mp4
# [F_20200220_1_0570_0600] Wrote 106 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0570_0600.txt
# [F_20200220_1_0570_0600] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0570_0600_tracked.mp4
# [F_20200220_1_0570_0600] Time: 114.78s, FPS ~ 6.53
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0600_0630 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0600_0630\img1_fixed.mp4
# [F_20200220_1_0600_0630] Wrote 50 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0600_0630.txt
# [F_20200220_1_0600_0630] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0600_0630_tracked.mp4
# [F_20200220_1_0600_0630] Time: 111.93s, FPS ~ 6.70
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0630_0660 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0630_0660\img1_fixed.mp4
# [F_20200220_1_0630_0660] Wrote 227 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0630_0660.txt
# [F_20200220_1_0630_0660] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0630_0660_tracked.mp4
# [F_20200220_1_0630_0660] Time: 110.13s, FPS ~ 6.81
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0660_0690 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0660_0690\img1_fixed.mp4
# [F_20200220_1_0660_0690] Wrote 16 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0660_0690.txt
# [F_20200220_1_0660_0690] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0660_0690_tracked.mp4
# [F_20200220_1_0660_0690] Time: 111.80s, FPS ~ 6.71
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0690_0720 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0690_0720\img1_fixed.mp4
# [F_20200220_1_0690_0720] Wrote 17 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0690_0720.txt
# [F_20200220_1_0690_0720] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0690_0720_tracked.mp4
# [F_20200220_1_0690_0720] Time: 110.10s, FPS ~ 6.81
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0720_0750 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0720_0750\img1_fixed.mp4
# [F_20200220_1_0720_0750] Wrote 22 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0720_0750.txt
# [F_20200220_1_0720_0750] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0720_0750_tracked.mp4
# [F_20200220_1_0720_0750] Time: 134.50s, FPS ~ 5.58
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0750_0780 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0750_0780\img1_fixed.mp4
# [F_20200220_1_0750_0780] Wrote 0 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0750_0780.txt
# [F_20200220_1_0750_0780] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0750_0780_tracked.mp4
# [F_20200220_1_0750_0780] Time: 110.30s, FPS ~ 6.80
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0780_0810 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0780_0810\img1_fixed.mp4
# [F_20200220_1_0780_0810] Wrote 28 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0780_0810.txt
# [F_20200220_1_0780_0810] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0780_0810_tracked.mp4
# [F_20200220_1_0780_0810] Time: 113.49s, FPS ~ 6.61
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0810_0840 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0810_0840\img1_fixed.mp4
# [F_20200220_1_0810_0840] Wrote 23 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0810_0840.txt
# [F_20200220_1_0810_0840] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0810_0840_tracked.mp4
# [F_20200220_1_0810_0840] Time: 113.32s, FPS ~ 6.62
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0840_0870 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0840_0870\img1_fixed.mp4
# [F_20200220_1_0840_0870] Wrote 8 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0840_0870.txt
# [F_20200220_1_0840_0870] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0840_0870_tracked.mp4
# [F_20200220_1_0840_0870] Time: 112.07s, FPS ~ 6.69
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20200220_1_0870_0900 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20200220_1_0870_0900\img1_fixed.mp4
# [F_20200220_1_0870_0900] Wrote 186 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20200220_1_0870_0900.txt
# [F_20200220_1_0870_0900] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20200220_1_0870_0900_tracked.mp4
# [F_20200220_1_0870_0900] Time: 109.70s, FPS ~ 6.84
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_0900_0930 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_0900_0930\img1_fixed.mp4
# [F_20220220_1_0900_0930] Wrote 19 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_0900_0930.txt
# [F_20220220_1_0900_0930] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_0900_0930_tracked.mp4
# [F_20220220_1_0900_0930] Time: 114.12s, FPS ~ 6.57
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_0930_0960 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_0930_0960\img1_fixed.mp4
# [F_20220220_1_0930_0960] Wrote 77 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_0930_0960.txt
# [F_20220220_1_0930_0960] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_0930_0960_tracked.mp4
# [F_20220220_1_0930_0960] Time: 122.18s, FPS ~ 6.14
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_0960_0990 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_0960_0990\img1_fixed.mp4
# [F_20220220_1_0960_0990] Wrote 35 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_0960_0990.txt
# [F_20220220_1_0960_0990] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_0960_0990_tracked.mp4
# [F_20220220_1_0960_0990] Time: 114.15s, FPS ~ 6.57
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_0990_1020 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_0990_1020\img1_fixed.mp4
# [F_20220220_1_0990_1020] Wrote 64 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_0990_1020.txt
# [F_20220220_1_0990_1020] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_0990_1020_tracked.mp4
# [F_20220220_1_0990_1020] Time: 123.98s, FPS ~ 6.05
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1020_1050 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1020_1050\img1_fixed.mp4
# [F_20220220_1_1020_1050] Wrote 27 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1020_1050.txt
# [F_20220220_1_1020_1050] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1020_1050_tracked.mp4
# [F_20220220_1_1020_1050] Time: 114.88s, FPS ~ 6.53
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1050_1080 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1050_1080\img1_fixed.mp4
# [F_20220220_1_1050_1080] Wrote 92 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1050_1080.txt
# [F_20220220_1_1050_1080] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1050_1080_tracked.mp4
# [F_20220220_1_1050_1080] Time: 115.01s, FPS ~ 6.52
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1080_1110 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1080_1110\img1_fixed.mp4
# [F_20220220_1_1080_1110] Wrote 44 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1080_1110.txt
# [F_20220220_1_1080_1110] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1080_1110_tracked.mp4
# [F_20220220_1_1080_1110] Time: 112.74s, FPS ~ 6.65
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1110_1140 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1110_1140\img1_fixed.mp4
# [F_20220220_1_1110_1140] Wrote 0 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1110_1140.txt
# [F_20220220_1_1110_1140] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1110_1140_tracked.mp4
# [F_20220220_1_1110_1140] Time: 113.29s, FPS ~ 6.62
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1140_1170 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1140_1170\img1_fixed.mp4
# [F_20220220_1_1140_1170] Wrote 0 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1140_1170.txt
# [F_20220220_1_1140_1170] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1140_1170_tracked.mp4
# [F_20220220_1_1140_1170] Time: 111.73s, FPS ~ 6.71
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1170_1200 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1170_1200\img1_fixed.mp4
# [F_20220220_1_1170_1200] Wrote 66 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1170_1200.txt
# [F_20220220_1_1170_1200] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1170_1200_tracked.mp4
# [F_20220220_1_1170_1200] Time: 116.81s, FPS ~ 6.42
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1200_1230 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1200_1230\img1_fixed.mp4
# [F_20220220_1_1200_1230] Wrote 176 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1200_1230.txt
# [F_20220220_1_1200_1230] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1200_1230_tracked.mp4
# [F_20220220_1_1200_1230] Time: 114.11s, FPS ~ 6.57
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1230_1260 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1230_1260\img1_fixed.mp4
# [F_20220220_1_1230_1260] Wrote 118 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1230_1260.txt
# [F_20220220_1_1230_1260] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1230_1260_tracked.mp4
# [F_20220220_1_1230_1260] Time: 115.30s, FPS ~ 6.51
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1260_1290 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1260_1290\img1_fixed.mp4
# [F_20220220_1_1260_1290] Wrote 172 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1260_1290.txt
# [F_20220220_1_1260_1290] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1260_1290_tracked.mp4
# [F_20220220_1_1260_1290] Time: 114.90s, FPS ~ 6.53
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1290_1320 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1290_1320\img1_fixed.mp4
# [F_20220220_1_1290_1320] Wrote 511 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1290_1320.txt
# [F_20220220_1_1290_1320] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1290_1320_tracked.mp4
# [F_20220220_1_1290_1320] Time: 119.71s, FPS ~ 6.27
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1320_1350 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1320_1350\img1_fixed.mp4
# [F_20220220_1_1320_1350] Wrote 89 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1320_1350.txt
# [F_20220220_1_1320_1350] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1320_1350_tracked.mp4
# [F_20220220_1_1320_1350] Time: 116.84s, FPS ~ 6.42
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1350_1380 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\train\F_20220220_1_1350_1380\img1_fixed.mp4
# [F_20220220_1_1350_1380] Wrote 91 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1350_1380.txt
# [F_20220220_1_1350_1380] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1350_1380_tracked.mp4
# [F_20220220_1_1350_1380] Time: 114.98s, FPS ~ 6.52
#
# All sequences processed. Output MOT files:
#   - F_20220220_1_1680_1710: results\yolov11_botsort\mot_outputs\F_20220220_1_1680_1710.txt
#   - F_20220220_1_1710_1740: results\yolov11_botsort\mot_outputs\F_20220220_1_1710_1740.txt
#   - F_20220220_1_1740_1770: results\yolov11_botsort\mot_outputs\F_20220220_1_1740_1770.txt
#   - F_20220220_1_1770_1800: results\yolov11_botsort\mot_outputs\F_20220220_1_1770_1800.txt
#   - F_20220220_1_1800_1830: results\yolov11_botsort\mot_outputs\F_20220220_1_1800_1830.txt
#   - F_20220220_1_1830_1860: results\yolov11_botsort\mot_outputs\F_20220220_1_1830_1860.txt
#   - F_20220220_1_1860_1890: results\yolov11_botsort\mot_outputs\F_20220220_1_1860_1890.txt
#   - F_20220220_1_1890_1920: results\yolov11_botsort\mot_outputs\F_20220220_1_1890_1920.txt
#   - F_20220220_1_1920_1950: results\yolov11_botsort\mot_outputs\F_20220220_1_1920_1950.txt
#   - F_20220220_1_1950_1980: results\yolov11_botsort\mot_outputs\F_20220220_1_1950_1980.txt
#   - F_20200220_1_0000_0030: results\yolov11_botsort\mot_outputs\F_20200220_1_0000_0030.txt
#   - F_20200220_1_0030_0060: results\yolov11_botsort\mot_outputs\F_20200220_1_0030_0060.txt
#   - F_20200220_1_0060_0090: results\yolov11_botsort\mot_outputs\F_20200220_1_0060_0090.txt
#   - F_20200220_1_0090_0120: results\yolov11_botsort\mot_outputs\F_20200220_1_0090_0120.txt
#   - F_20200220_1_0120_0150: results\yolov11_botsort\mot_outputs\F_20200220_1_0120_0150.txt
#   - F_20200220_1_0150_0180: results\yolov11_botsort\mot_outputs\F_20200220_1_0150_0180.txt
#   - F_20200220_1_0180_0210: results\yolov11_botsort\mot_outputs\F_20200220_1_0180_0210.txt
#   - F_20200220_1_0210_0240: results\yolov11_botsort\mot_outputs\F_20200220_1_0210_0240.txt
#   - F_20200220_1_0240_0270: results\yolov11_botsort\mot_outputs\F_20200220_1_0240_0270.txt
#   - F_20200220_1_0270_0300: results\yolov11_botsort\mot_outputs\F_20200220_1_0270_0300.txt
#   - F_20200220_1_0300_0330: results\yolov11_botsort\mot_outputs\F_20200220_1_0300_0330.txt
#   - F_20200220_1_0330_0360: results\yolov11_botsort\mot_outputs\F_20200220_1_0330_0360.txt
#   - F_20200220_1_0360_0390: results\yolov11_botsort\mot_outputs\F_20200220_1_0360_0390.txt
#   - F_20200220_1_0390_0420: results\yolov11_botsort\mot_outputs\F_20200220_1_0390_0420.txt
#   - F_20200220_1_0420_0450: results\yolov11_botsort\mot_outputs\F_20200220_1_0420_0450.txt
#   - F_20200220_1_0450_0480: results\yolov11_botsort\mot_outputs\F_20200220_1_0450_0480.txt
#   - F_20200220_1_0480_0510: results\yolov11_botsort\mot_outputs\F_20200220_1_0480_0510.txt
#   - F_20200220_1_0510_0540: results\yolov11_botsort\mot_outputs\F_20200220_1_0510_0540.txt
#   - F_20200220_1_0540_0570: results\yolov11_botsort\mot_outputs\F_20200220_1_0540_0570.txt
#   - F_20200220_1_0570_0600: results\yolov11_botsort\mot_outputs\F_20200220_1_0570_0600.txt
#   - F_20200220_1_0600_0630: results\yolov11_botsort\mot_outputs\F_20200220_1_0600_0630.txt
#   - F_20200220_1_0630_0660: results\yolov11_botsort\mot_outputs\F_20200220_1_0630_0660.txt
#   - F_20200220_1_0660_0690: results\yolov11_botsort\mot_outputs\F_20200220_1_0660_0690.txt
#   - F_20200220_1_0690_0720: results\yolov11_botsort\mot_outputs\F_20200220_1_0690_0720.txt
#   - F_20200220_1_0720_0750: results\yolov11_botsort\mot_outputs\F_20200220_1_0720_0750.txt
#   - F_20200220_1_0750_0780: results\yolov11_botsort\mot_outputs\F_20200220_1_0750_0780.txt
#   - F_20200220_1_0780_0810: results\yolov11_botsort\mot_outputs\F_20200220_1_0780_0810.txt
#   - F_20200220_1_0810_0840: results\yolov11_botsort\mot_outputs\F_20200220_1_0810_0840.txt
#   - F_20200220_1_0840_0870: results\yolov11_botsort\mot_outputs\F_20200220_1_0840_0870.txt
#   - F_20200220_1_0870_0900: results\yolov11_botsort\mot_outputs\F_20200220_1_0870_0900.txt
#   - F_20220220_1_0900_0930: results\yolov11_botsort\mot_outputs\F_20220220_1_0900_0930.txt
#   - F_20220220_1_0930_0960: results\yolov11_botsort\mot_outputs\F_20220220_1_0930_0960.txt
#   - F_20220220_1_0960_0990: results\yolov11_botsort\mot_outputs\F_20220220_1_0960_0990.txt
#   - F_20220220_1_0990_1020: results\yolov11_botsort\mot_outputs\F_20220220_1_0990_1020.txt
#   - F_20220220_1_1020_1050: results\yolov11_botsort\mot_outputs\F_20220220_1_1020_1050.txt
#   - F_20220220_1_1050_1080: results\yolov11_botsort\mot_outputs\F_20220220_1_1050_1080.txt
#   - F_20220220_1_1080_1110: results\yolov11_botsort\mot_outputs\F_20220220_1_1080_1110.txt
#   - F_20220220_1_1110_1140: results\yolov11_botsort\mot_outputs\F_20220220_1_1110_1140.txt
#   - F_20220220_1_1140_1170: results\yolov11_botsort\mot_outputs\F_20220220_1_1140_1170.txt
#   - F_20220220_1_1170_1200: results\yolov11_botsort\mot_outputs\F_20220220_1_1170_1200.txt
#   - F_20220220_1_1200_1230: results\yolov11_botsort\mot_outputs\F_20220220_1_1200_1230.txt
#   - F_20220220_1_1230_1260: results\yolov11_botsort\mot_outputs\F_20220220_1_1230_1260.txt
#   - F_20220220_1_1260_1290: results\yolov11_botsort\mot_outputs\F_20220220_1_1260_1290.txt
#   - F_20220220_1_1290_1320: results\yolov11_botsort\mot_outputs\F_20220220_1_1290_1320.txt
#   - F_20220220_1_1320_1350: results\yolov11_botsort\mot_outputs\F_20220220_1_1320_1350.txt
#   - F_20220220_1_1350_1380: results\yolov11_botsort\mot_outputs\F_20220220_1_1350_1380.txt
