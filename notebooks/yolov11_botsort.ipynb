# %%
# !ffmpeg -version
# Out:
# 'ffmpeg' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from pathlib import Path
import os
import csv
import time

import numpy as np
import torch
from ultralytics import YOLO

# Root paths (work relative to repo root)
REPO_ROOT = Path.cwd().resolve()
DATA_ROOT = REPO_ROOT / "data" / "soccer_side"
RESULTS_ROOT = REPO_ROOT / "results" / "yolov11_botsort"

RESULTS_ROOT.mkdir(parents=True, exist_ok=True)

print(f"Repo root: {REPO_ROOT}")
print(f"Data root: {DATA_ROOT}")
print(f"Results root: {RESULTS_ROOT}")

# Device selection
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"

print("Using device:", DEVICE)
# Out:
# Repo root: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker
# Data root: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side
# Results root: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort
# Using device: cpu

# %%
# Pre-process videos: convert to fixed format using ffmpeg
# This ensures compatibility with video processing libraries
import subprocess
import glob
# Use specific ffmpeg path
ffmpeg_path = r"C:\Users\rishi\ffmpeg\bin\ffmpeg.exe"

# Check if ffmpeg exists at the specified path
if not os.path.exists(ffmpeg_path):
    print(f"[ERROR] ffmpeg not found at: {ffmpeg_path}")
    print("Please update the ffmpeg_path variable in this cell with the correct path.")
    print("Skipping video preprocessing.")
else:
    print(f"Using ffmpeg at: {ffmpeg_path}")
    print("Pre-processing videos to fixed format...")
    videos_processed = 0
    videos_skipped = 0
    videos_failed = 0

    for vid in glob.glob("data/soccer_side/**/*.mp4", recursive=True):
        # Skip if it's already a _fixed.mp4 file
        if "_fixed.mp4" in vid:
            continue
        
        fixed = vid.replace(".mp4", "_fixed.mp4")
        
        if not os.path.exists(fixed):
            print(f"Processing: {vid} -> {fixed}")
            try:
                result = subprocess.run([
                    ffmpeg_path, "-y", "-i", vid,
                    "-c:v", "libx264", "-pix_fmt", "yuv420p",
                    "-c:a", "aac", fixed
                ], capture_output=True, text=True, timeout=300)  # 5 minute timeout per video
                
                if result.returncode == 0:
                    videos_processed += 1
                    print(f"  ✓ Success")
                else:
                    videos_failed += 1
                    print(f"  ✗ Failed: {result.stderr[:200]}")  # Show first 200 chars of error
            except subprocess.TimeoutExpired:
                videos_failed += 1
                print(f"  ✗ Timeout (video too long or stuck)")
            except Exception as e:
                videos_failed += 1
                print(f"  ✗ Error: {str(e)}")
        else:
            videos_skipped += 1

    print(f"\nPre-processing complete:")
    print(f"  - Processed: {videos_processed} video(s)")
    print(f"  - Already fixed: {videos_skipped} video(s)")
    if videos_failed > 0:
        print(f"  - Failed: {videos_failed} video(s)")
# Out:
# Using ffmpeg at: C:\Users\rishi\ffmpeg\bin\ffmpeg.exe
# Pre-processing videos to fixed format...
# Processing: data/soccer_side\test\F_20220220_1_1680_1710\img1.mp4 -> data/soccer_side\test\F_20220220_1_1680_1710\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\test\F_20220220_1_1710_1740\img1.mp4 -> data/soccer_side\test\F_20220220_1_1710_1740\img1_fixed.mp4
#   ✓ Success
# Processing: data/soccer_side\test\F_20220220_1_1740_1770\img1.mp4 -> data/soccer_side\test\F_20220220_1_1740_1770\img1_fixed.mp4

# %%
VIDEO_EXTS = {".mp4", ".mkv", ".avi", ".mov"}

def discover_sequences(data_root: Path):
    """
    Discover all sequences under data_root that:
    - Have a gt/gt.txt file
    - Have at least one video file in the same parent directory as gt/
    
    Prefers _fixed.mp4 files over regular .mp4 files for better compatibility.
    """
    seqs = []

    for gt_file in data_root.rglob("gt.txt"):
        gt_dir = gt_file.parent              # .../seq_name/gt
        seq_dir = gt_dir.parent              # .../seq_name
        video_files = [
            p for p in seq_dir.iterdir()
            if p.is_file() and p.suffix.lower() in VIDEO_EXTS
        ]

        if not video_files:
            # No video attached to this gt; skip
            continue

        # Prefer _fixed.mp4 files over regular .mp4 files
        fixed_videos = [v for v in video_files if "_fixed.mp4" in v.name]
        if fixed_videos:
            # Use _fixed.mp4 if available
            video_files = fixed_videos
        else:
            # Otherwise prefer .mp4 over other formats
            mp4_videos = [v for v in video_files if v.suffix.lower() == ".mp4"]
            if mp4_videos:
                video_files = mp4_videos

        # If multiple videos exist, pick the first alphabetically and warn
        video_files.sort()
        video_path = video_files[0]
        if len(video_files) > 1:
            print(f"[WARN] Multiple videos in {seq_dir}, using {video_path.name}")

        seqs.append(
            {
                "name": seq_dir.name,
                "seq_dir": seq_dir,
                "gt_path": gt_file,
                "video_path": video_path,
            }
        )

    return seqs

sequences = discover_sequences(DATA_ROOT)

print(f"Discovered {len(sequences)} sequence(s) with video + gt:")
for s in sequences:
    print(f"  - {s['name']}: video={s['video_path'].relative_to(REPO_ROOT)}, gt={s['gt_path'].relative_to(REPO_ROOT)}")
# Out:
# Discovered 56 sequence(s) with video + gt:
#   - F_20220220_1_1680_1710: video=data\soccer_side\test\F_20220220_1_1680_1710\img1.mp4, gt=data\soccer_side\test\F_20220220_1_1680_1710\gt\gt.txt
#   - F_20220220_1_1710_1740: video=data\soccer_side\test\F_20220220_1_1710_1740\img1.mp4, gt=data\soccer_side\test\F_20220220_1_1710_1740\gt\gt.txt
#   - F_20220220_1_1740_1770: video=data\soccer_side\test\F_20220220_1_1740_1770\img1.mp4, gt=data\soccer_side\test\F_20220220_1_1740_1770\gt\gt.txt
#   - F_20220220_1_1770_1800: video=data\soccer_side\test\F_20220220_1_1770_1800\img1.mp4, gt=data\soccer_side\test\F_20220220_1_1770_1800\gt\gt.txt
#   - F_20220220_1_1800_1830: video=data\soccer_side\test\F_20220220_1_1800_1830\img1.mp4, gt=data\soccer_side\test\F_20220220_1_1800_1830\gt\gt.txt
#   - F_20220220_1_1830_1860: video=data\soccer_side\test\F_20220220_1_1830_1860\img1.mp4, gt=data\soccer_side\test\F_20220220_1_1830_1860\gt\gt.txt
#   - F_20220220_1_1860_1890: video=data\soccer_side\test\F_20220220_1_1860_1890\img1.mp4, gt=data\soccer_side\test\F_20220220_1_1860_1890\gt\gt.txt
#   - F_20220220_1_1890_1920: video=data\soccer_side\test\F_20220220_1_1890_1920\img1.mp4, gt=data\soccer_side\test\F_20220220_1_1890_1920\gt\gt.txt
#   - F_20220220_1_1920_1950: video=data\soccer_side\test\F_20220220_1_1920_1950\img1.mp4, gt=data\soccer_side\test\F_20220220_1_1920_1950\gt\gt.txt
#   - F_20220220_1_1950_1980: video=data\soccer_side\test\F_20220220_1_1950_1980\img1.mp4, gt=data\soccer_side\test\F_20220220_1_1950_1980\gt\gt.txt
#   - F_20200220_1_0000_0030: video=data\soccer_side\train\F_20200220_1_0000_0030\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0000_0030\gt\gt.txt
#   - F_20200220_1_0030_0060: video=data\soccer_side\train\F_20200220_1_0030_0060\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0030_0060\gt\gt.txt
#   - F_20200220_1_0060_0090: video=data\soccer_side\train\F_20200220_1_0060_0090\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0060_0090\gt\gt.txt
#   - F_20200220_1_0090_0120: video=data\soccer_side\train\F_20200220_1_0090_0120\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0090_0120\gt\gt.txt
#   - F_20200220_1_0120_0150: video=data\soccer_side\train\F_20200220_1_0120_0150\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0120_0150\gt\gt.txt
#   - F_20200220_1_0150_0180: video=data\soccer_side\train\F_20200220_1_0150_0180\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0150_0180\gt\gt.txt
#   - F_20200220_1_0180_0210: video=data\soccer_side\train\F_20200220_1_0180_0210\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0180_0210\gt\gt.txt
#   - F_20200220_1_0210_0240: video=data\soccer_side\train\F_20200220_1_0210_0240\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0210_0240\gt\gt.txt
#   - F_20200220_1_0240_0270: video=data\soccer_side\train\F_20200220_1_0240_0270\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0240_0270\gt\gt.txt
#   - F_20200220_1_0270_0300: video=data\soccer_side\train\F_20200220_1_0270_0300\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0270_0300\gt\gt.txt
#   - F_20200220_1_0300_0330: video=data\soccer_side\train\F_20200220_1_0300_0330\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0300_0330\gt\gt.txt
#   - F_20200220_1_0330_0360: video=data\soccer_side\train\F_20200220_1_0330_0360\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0330_0360\gt\gt.txt
#   - F_20200220_1_0360_0390: video=data\soccer_side\train\F_20200220_1_0360_0390\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0360_0390\gt\gt.txt
#   - F_20200220_1_0390_0420: video=data\soccer_side\train\F_20200220_1_0390_0420\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0390_0420\gt\gt.txt
#   - F_20200220_1_0420_0450: video=data\soccer_side\train\F_20200220_1_0420_0450\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0420_0450\gt\gt.txt
#   - F_20200220_1_0450_0480: video=data\soccer_side\train\F_20200220_1_0450_0480\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0450_0480\gt\gt.txt
#   - F_20200220_1_0480_0510: video=data\soccer_side\train\F_20200220_1_0480_0510\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0480_0510\gt\gt.txt
#   - F_20200220_1_0510_0540: video=data\soccer_side\train\F_20200220_1_0510_0540\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0510_0540\gt\gt.txt
#   - F_20200220_1_0540_0570: video=data\soccer_side\train\F_20200220_1_0540_0570\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0540_0570\gt\gt.txt
#   - F_20200220_1_0570_0600: video=data\soccer_side\train\F_20200220_1_0570_0600\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0570_0600\gt\gt.txt
#   - F_20200220_1_0600_0630: video=data\soccer_side\train\F_20200220_1_0600_0630\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0600_0630\gt\gt.txt
#   - F_20200220_1_0630_0660: video=data\soccer_side\train\F_20200220_1_0630_0660\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0630_0660\gt\gt.txt
#   - F_20200220_1_0660_0690: video=data\soccer_side\train\F_20200220_1_0660_0690\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0660_0690\gt\gt.txt
#   - F_20200220_1_0690_0720: video=data\soccer_side\train\F_20200220_1_0690_0720\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0690_0720\gt\gt.txt
#   - F_20200220_1_0720_0750: video=data\soccer_side\train\F_20200220_1_0720_0750\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0720_0750\gt\gt.txt
#   - F_20200220_1_0750_0780: video=data\soccer_side\train\F_20200220_1_0750_0780\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0750_0780\gt\gt.txt
#   - F_20200220_1_0780_0810: video=data\soccer_side\train\F_20200220_1_0780_0810\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0780_0810\gt\gt.txt
#   - F_20200220_1_0810_0840: video=data\soccer_side\train\F_20200220_1_0810_0840\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0810_0840\gt\gt.txt
#   - F_20200220_1_0840_0870: video=data\soccer_side\train\F_20200220_1_0840_0870\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0840_0870\gt\gt.txt
#   - F_20200220_1_0870_0900: video=data\soccer_side\train\F_20200220_1_0870_0900\img1.mp4, gt=data\soccer_side\train\F_20200220_1_0870_0900\gt\gt.txt
#   - F_20220220_1_0900_0930: video=data\soccer_side\train\F_20220220_1_0900_0930\img1.mp4, gt=data\soccer_side\train\F_20220220_1_0900_0930\gt\gt.txt
#   - F_20220220_1_0930_0960: video=data\soccer_side\train\F_20220220_1_0930_0960\img1.mp4, gt=data\soccer_side\train\F_20220220_1_0930_0960\gt\gt.txt
#   - F_20220220_1_0960_0990: video=data\soccer_side\train\F_20220220_1_0960_0990\img1.mp4, gt=data\soccer_side\train\F_20220220_1_0960_0990\gt\gt.txt
#   - F_20220220_1_0990_1020: video=data\soccer_side\train\F_20220220_1_0990_1020\img1.mp4, gt=data\soccer_side\train\F_20220220_1_0990_1020\gt\gt.txt
#   - F_20220220_1_1020_1050: video=data\soccer_side\train\F_20220220_1_1020_1050\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1020_1050\gt\gt.txt
#   - F_20220220_1_1050_1080: video=data\soccer_side\train\F_20220220_1_1050_1080\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1050_1080\gt\gt.txt
#   - F_20220220_1_1080_1110: video=data\soccer_side\train\F_20220220_1_1080_1110\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1080_1110\gt\gt.txt
#   - F_20220220_1_1110_1140: video=data\soccer_side\train\F_20220220_1_1110_1140\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1110_1140\gt\gt.txt
#   - F_20220220_1_1140_1170: video=data\soccer_side\train\F_20220220_1_1140_1170\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1140_1170\gt\gt.txt
#   - F_20220220_1_1170_1200: video=data\soccer_side\train\F_20220220_1_1170_1200\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1170_1200\gt\gt.txt
#   - F_20220220_1_1200_1230: video=data\soccer_side\train\F_20220220_1_1200_1230\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1200_1230\gt\gt.txt
#   - F_20220220_1_1230_1260: video=data\soccer_side\train\F_20220220_1_1230_1260\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1230_1260\gt\gt.txt
#   - F_20220220_1_1260_1290: video=data\soccer_side\train\F_20220220_1_1260_1290\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1260_1290\gt\gt.txt
#   - F_20220220_1_1290_1320: video=data\soccer_side\train\F_20220220_1_1290_1320\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1290_1320\gt\gt.txt
#   - F_20220220_1_1320_1350: video=data\soccer_side\train\F_20220220_1_1320_1350\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1320_1350\gt\gt.txt
#   - F_20220220_1_1350_1380: video=data\soccer_side\train\F_20220220_1_1350_1380\img1.mp4, gt=data\soccer_side\train\F_20220220_1_1350_1380\gt\gt.txt

# %%
# You can switch to 'yolo11s.pt' or larger if you want better accuracy and have GPU resources
YOLO_WEIGHTS = "yolo11n.pt"   # or "yolo11s.pt"

print(f"Loading YOLOv11 model from weights: {YOLO_WEIGHTS}")
yolo_model = YOLO(YOLO_WEIGHTS)
yolo_model.to(DEVICE)

# COCO class index for 'person' is 0
PERSON_CLASS_ID = 0
# Out:
# Loading YOLOv11 model from weights: yolo11n.pt

# %%
def track_sequence_with_yolo_botsort(
    model: YOLO,
    video_path: Path,
    seq_name: str,
    save_dir: Path,
    classes=(PERSON_CLASS_ID,),
    conf: float = 0.25,
    iou: float = 0.5,
    device: str = DEVICE,
    save_video: bool = True,
):
    """
    Run YOLOv11 + BoT-SORT on a single video and export detections in MOT format.
    Optionally saves annotated video with tracking visualizations in MP4 format.

    Parameters
    ----------
    model : YOLO
        Ultralytics YOLO model instance.
    video_path : Path
        Path to the input video.
    seq_name : str
        Name of the sequence (used for result filename).
    save_dir : Path
        Directory to write MOT-format result file into.
    classes : tuple
        Tuple of class IDs to keep (default: person only).
    conf : float
        Confidence threshold.
    iou : float
        IoU threshold for NMS.
    device : str
        "cuda" or "cpu".
    save_video : bool
        If True, save annotated video with tracking visualizations.
    """
    import cv2
    
    save_dir.mkdir(parents=True, exist_ok=True)
    mot_out_path = save_dir / f"{seq_name}.txt"
    video_out_dir = save_dir / "videos"
    video_out_dir.mkdir(exist_ok=True)
    video_out_path = video_out_dir / f"{seq_name}_tracked.mp4"

    # Open CSV writer for MOTChallenge-style output
    f = open(mot_out_path, "w", newline="")
    writer = csv.writer(f)

    frame_idx = 0
    t_start = time.time()

    # Initialize video writer if saving video
    video_writer = None
    if save_video:
        # Get video properties from input video
        cap = cv2.VideoCapture(str(video_path))
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        cap.release()
        
        # Use MP4 codec (H.264)
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        video_writer = cv2.VideoWriter(str(video_out_path), fourcc, fps, (width, height))

    # Run tracking - use streaming mode to process frame by frame
    # This allows us to manually write MP4 videos
    results_generator = model.track(
        source=str(video_path),
        tracker="botsort.yaml",
        conf=conf,
        iou=iou,
        classes=list(classes),
        device=device,
        stream=True,  # Use streaming to get annotated frames
        verbose=False,
        save=False,  # Don't use Ultralytics' built-in saving (saves as AVI)
    )

    # Process results to write MOT format and save video frames
    num_det_total = 0
    for res in results_generator:
        frame_idx += 1  # MOT frames are 1-based
        boxes = res.boxes

        # Get annotated frame (with bounding boxes drawn)
        annotated_frame = res.plot()  # This returns the frame with annotations
        
        # Write frame to video if saving
        if save_video and video_writer is not None:
            # Convert BGR to RGB (plot() returns RGB, OpenCV needs BGR)
            frame_bgr = cv2.cvtColor(annotated_frame, cv2.COLOR_RGB2BGR)
            video_writer.write(frame_bgr)

        if boxes is None or boxes.id is None:
            continue

        ids = boxes.id.cpu().numpy().astype(int)
        xyxy = boxes.xyxy.cpu().numpy()
        confs = boxes.conf.cpu().numpy()

        for trk_id, (x1, y1, x2, y2), c in zip(ids, xyxy, confs):
            w = x2 - x1
            h = y2 - y1

            # MOT format: frame, id, bb_left, bb_top, bb_width, bb_height, conf, -1, -1, -1
            writer.writerow([
                frame_idx,
                int(trk_id),
                float(x1),
                float(y1),
                float(w),
                float(h),
                float(c),
                -1,
                -1,
                -1,
            ])
            num_det_total += 1

    f.close()
    if save_video and video_writer is not None:
        video_writer.release()
    
    t_end = time.time()
    elapsed = t_end - t_start

    print(f"[{seq_name}] Wrote {num_det_total} detections to {mot_out_path}")
    if save_video and video_out_path.exists():
        print(f"[{seq_name}] Saved annotated video to {video_out_path}")
    print(f"[{seq_name}] Time: {elapsed:.2f}s, FPS ~ {frame_idx / elapsed if elapsed > 0 else 0:.2f}")

    return mot_out_path

# %%
mot_results_dir = RESULTS_ROOT / "mot_outputs"
mot_results_dir.mkdir(parents=True, exist_ok=True)

result_paths = {}

for seq in sequences:
    name = seq["name"]
    video_path = seq["video_path"]

    print(f"\n=== Running YOLOv11 + BoT-SORT on sequence: {name} ===")
    print(f"Video: {video_path}")

    out_path = track_sequence_with_yolo_botsort(
        model=yolo_model,
        video_path=video_path,
        seq_name=name,
        save_dir=mot_results_dir,
        classes=(PERSON_CLASS_ID,),
        conf=0.25,
        iou=0.5,
        device=DEVICE,
    )
    result_paths[name] = out_path

print("\nAll sequences processed. Output MOT files:")
for name, path in result_paths.items():
    print(f"  - {name}: {path.relative_to(REPO_ROOT)}")
# Out:
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1680_1710 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1680_1710\img1.mp4
# [F_20220220_1_1680_1710] Wrote 70 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1680_1710.txt
# [F_20220220_1_1680_1710] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1680_1710_tracked.mp4
# [F_20220220_1_1680_1710] Time: 112.62s, FPS ~ 6.66
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1710_1740 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1710_1740\img1.mp4
# [F_20220220_1_1710_1740] Wrote 0 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1710_1740.txt
# [F_20220220_1_1710_1740] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1710_1740_tracked.mp4
# [F_20220220_1_1710_1740] Time: 112.82s, FPS ~ 6.65
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1740_1770 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1740_1770\img1.mp4
# [F_20220220_1_1740_1770] Wrote 120 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1740_1770.txt
# [F_20220220_1_1740_1770] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1740_1770_tracked.mp4
# [F_20220220_1_1740_1770] Time: 116.64s, FPS ~ 6.43
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1770_1800 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1770_1800\img1.mp4
# [F_20220220_1_1770_1800] Wrote 384 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1770_1800.txt
# [F_20220220_1_1770_1800] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1770_1800_tracked.mp4
# [F_20220220_1_1770_1800] Time: 111.92s, FPS ~ 6.70
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1800_1830 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1800_1830\img1.mp4
# [F_20220220_1_1800_1830] Wrote 95 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1800_1830.txt
# [F_20220220_1_1800_1830] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1800_1830_tracked.mp4
# [F_20220220_1_1800_1830] Time: 117.76s, FPS ~ 6.37
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1830_1860 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1830_1860\img1.mp4
# [F_20220220_1_1830_1860] Wrote 10 detections to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\F_20220220_1_1830_1860.txt
# [F_20220220_1_1830_1860] Saved annotated video to C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\results\yolov11_botsort\mot_outputs\videos\F_20220220_1_1830_1860_tracked.mp4
# [F_20220220_1_1830_1860] Time: 148.26s, FPS ~ 5.06
#
# === Running YOLOv11 + BoT-SORT on sequence: F_20220220_1_1860_1890 ===
# Video: C:\Users\rishi\OneDrive\College\CS543\sports-data-tracker\data\soccer_side\test\F_20220220_1_1860_1890\img1.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 13
#      10     print(f"\n=== Running YOLOv11 + BoT-SORT on sequence: {name} ===")
#      11     print(f"Video: {video_path}")
# ---> 13     out_path = track_sequence_with_yolo_botsort(
#      14         model=yolo_model,
#      15         video_path=video_path,
#      16         seq_name=name,
#      17         save_dir=mot_results_dir,
#      18         classes=(PERSON_CLASS_ID,),
#      19         conf=0.25,
#      20         iou=0.5,
#      21         device=DEVICE,
#      22     )
#      23     result_paths[name] = out_path
#      25 print("\nAll sequences processed. Output MOT files:")
#
# Cell In[20], line 82, in track_sequence_with_yolo_botsort(model, video_path, seq_name, save_dir, classes, conf, iou, device, save_video)
#      80 # Process results to write MOT format and save video frames
#      81 num_det_total = 0
# ---> 82 for res in results_generator:
#      83     frame_idx += 1  # MOT frames are 1-based
#      84     boxes = res.boxes
#
# File ~\OneDrive\College\CS543\sports-data-tracker\.venv\lib\site-packages\torch\utils\_contextlib.py:59, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      56         else:
#      57             # Pass the last request to the generator and get its response
#      58             with ctx_factory():
# ---> 59                 response = gen.send(request)
#      61 # We let the exceptions raised above by the generator's `.throw` or
#      62 # `.send` methods bubble up to our caller, except for StopIteration
#      63 except StopIteration as e:
#      64     # The generator informed us that it is done: take whatever its
#      65     # returned value (if any) was and indicate that we're done too
#      66     # by returning it (see docs for python's return-statement).
#
# File ~\OneDrive\College\CS543\sports-data-tracker\.venv\lib\site-packages\ultralytics\engine\predictor.py:336, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     334 with profilers[2]:
#     335     self.results = self.postprocess(preds, im, im0s)
# --> 336 self.run_callbacks("on_predict_postprocess_end")
#     338 # Visualize, save, write results
#     339 n = len(im0s)
#
# File ~\OneDrive\College\CS543\sports-data-tracker\.venv\lib\site-packages\ultralytics\engine\predictor.py:502, in BasePredictor.run_callbacks(self, event)
#     500 """Run all registered callbacks for a specific event."""
#     501 for callback in self.callbacks.get(event, []):
# --> 502     callback(self)
#
# File ~\OneDrive\College\CS543\sports-data-tracker\.venv\lib\site-packages\ultralytics\trackers\track.py:93, in on_predict_postprocess_end(predictor, persist)
#      90     predictor.vid_path[i if is_stream else 0] = vid_path
#      92 det = (result.obb if is_obb else result.boxes).cpu().numpy()
# ---> 93 tracks = tracker.update(det, result.orig_img, getattr(result, "feats", None))
#      94 if len(tracks) == 0:
#      95     continue
#
# File ~\OneDrive\College\CS543\sports-data-tracker\.venv\lib\site-packages\ultralytics\trackers\byte_tracker.py:331, in BYTETracker.update(self, results, img, feats)
#     328 if hasattr(self, "gmc") and img is not None:
#     329     # use try-except here to bypass errors from gmc module
#     330     try:
# --> 331         warp = self.gmc.apply(img, results.xyxy)
#     332     except Exception:
#     333         warp = np.eye(2, 3)
#
# File ~\OneDrive\College\CS543\sports-data-tracker\.venv\lib\site-packages\ultralytics\trackers\utils\gmc.py:113, in GMC.apply(self, raw_frame, detections)
#     111     return self.apply_ecc(raw_frame)
#     112 elif self.method == "sparseOptFlow":
# --> 113     return self.apply_sparseoptflow(raw_frame)
#     114 else:
#     115     return np.eye(2, 3)
#
# File ~\OneDrive\College\CS543\sports-data-tracker\.venv\lib\site-packages\ultralytics\trackers\utils\gmc.py:295, in GMC.apply_sparseoptflow(self, raw_frame)
#     293 # Downscale image for computational efficiency
#     294 if self.downscale > 1.0:
# --> 295     frame = cv2.resize(frame, (width // self.downscale, height // self.downscale))
#     297 # Find good features to track
#     298 keypoints = cv2.goodFeaturesToTrack(frame, mask=None, **self.feature_params)
#
# KeyboardInterrupt:
